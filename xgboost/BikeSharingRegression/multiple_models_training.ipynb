# %% [markdown]
# # XGBoost - Two different models
# ### Train bike rental dataset with different hyperparameters
#
# SageMaker SDK Documentation: https://sagemaker.readthedocs.io/en/latest/overview.html

# %%
import numpy as np
import pandas as pd

import boto3
import re

import sagemaker
from sagemaker import get_execution_role

# %% [markdown]
# ## Upload Data to S3

# %%
# Specify your bucket name
bucket_name = 'chandra-ml-sagemaker'

training_folder = r'bikerental-hyper/training/'
validation_folder = r'bikerental-hyper/validation/'
test_folder = r'bikerental-hyper/test/'

s3_model_output_location = r's3://{0}/bikerental-hyper/model'.format(bucket_name)
s3_training_file_location = r's3://{0}/{1}'.format(bucket_name,training_folder)
s3_validation_file_location = r's3://{0}/{1}'.format(bucket_name,validation_folder)
s3_test_file_location = r's3://{0}/{1}'.format(bucket_name,test_folder)

# %%
print(s3_model_output_location)
print(s3_training_file_location)
print(s3_validation_file_location)
print(s3_test_file_location)
# Out:
# s3://chandra-ml-sagemaker/bikerental-hyper/model
# s3://chandra-ml-sagemaker/bikerental-hyper/training/
# s3://chandra-ml-sagemaker/bikerental-hyper/validation/
# s3://chandra-ml-sagemaker/bikerental-hyper/test/

# %%
# Data Channels for the training algorithm
# content type can be libsvm or csv for XGBoost
training_input_config = sagemaker.session.TrainingInput(
    s3_data=s3_training_file_location,
    content_type='csv',
    s3_data_type='S3Prefix')

validation_input_config = sagemaker.session.TrainingInput(
    s3_data=s3_validation_file_location,
    content_type='csv',
    s3_data_type='S3Prefix'
)

data_channels = {'train': training_input_config, 'validation': validation_input_config}

# %%
# Write and Reading from S3 is just as easy
# files are referred as objects in S3.  
# file name is referred as key name in S3

# File stored in S3 is automatically replicated across 3 different availability zones 
# in the region where the bucket was created.

# http://boto3.readthedocs.io/en/latest/guide/s3.html
def write_to_s3(filename, bucket, key):
    with open(filename,'rb') as f: # Read in binary mode
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(f)

# %%
write_to_s3('bike_train.csv', 
            bucket_name,
            training_folder + 'bike_train.csv')

write_to_s3('bike_validation.csv',
            bucket_name,
            validation_folder + 'bike_validation.csv')

write_to_s3('bike_test.csv',
            bucket_name,
            test_folder + 'bike_test.csv')

# %% [markdown]
# ## Training Algorithm Docker Image
# ### SageMaker maintains a separate image for algorithm and region
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# %%
# Use Spot Instance - Save up to 90% of training cost by using spot instances when compared to on-demand instances
# Reference: https://github.com/aws-samples/amazon-sagemaker-managed-spot-training/blob/main/xgboost_built_in_managed_spot_training_checkpointing/xgboost_built_in_managed_spot_training_checkpointing.ipynb

# if you are still on two-month free-tier you can use the on-demand instance by setting:
#   use_spot_instances = False

# We will use spot for training
use_spot_instances = True
max_run = 3600 # in seconds
max_wait = 7200 if use_spot_instances else None # in seconds

# %%
def fit_model(jobSuffix, hyperParameters):
    # Establish a session with AWS
    sess = sagemaker.Session()
    # This role contains the permissions needed to train, deploy models    
    role = get_execution_role()
    
    # job name has the version details - replace "." with "-"
    job_name = f"xgboost-bikerental-{jobSuffix}"
    
    print (f"***Job name: {job_name}***")
    
    checkpoint_s3_uri = None

    if use_spot_instances:
        checkpoint_s3_uri = f's3://{bucket_name}/bikerental-hyper/checkpoints/{job_name}'

    print (f'Checkpoint uri: {checkpoint_s3_uri}')
            
    # Use the specified version of XGBoost
    container = sagemaker.image_uris.retrieve("xgboost",
                                              sess.boto_region_name,
                                              version="1.2-2")

    print (f'Using XGBoost Container {container}')
    
    # Configure the training job
    # for managed spot training, specify the use_spot_instances flag, max_run, max_wait and checkpoint_s3_uri
    estimator = sagemaker.estimator.Estimator(
        container,
        role,
        instance_count=1,
        instance_type='ml.m5.xlarge',
        output_path=s3_model_output_location,
        sagemaker_session=sess,
        base_job_name = job_name,
        hyperparameters = hyperParameters,
        use_spot_instances=use_spot_instances,
        max_run=max_run,
        max_wait=max_wait,
        checkpoint_s3_uri=checkpoint_s3_uri)

    estimator.fit(data_channels)

    return estimator.latest_training_job.name

# %%
# XGBoost hyperparameters
hyperParametersOne = {"objective":"reg:squarederror",                   
                      "eta":0.1,
                      "max_depth":5,
                      "num_round":150}

# Adjust depth and round
hyperParametersTwo = {"objective":"reg:squarederror",
                      "eta":0.1,
                      "max_depth":7,
                      "num_round":200}

# %%
fit_model(jobSuffix="hyper-one", hyperParameters=hyperParametersOne)
# Out:
# ***Job name: xgboost-bikerental-hyper-one***
# Checkpoint uri: s3://chandra-ml-sagemaker/bikerental-hyper/checkpoints/xgboost-bikerental-hyper-one
# Using XGBoost Container 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-2
# 2021-06-29 19:03:52 Starting - Starting the training job...
# 2021-06-29 19:04:15 Starting - Launching requested ML instancesProfilerReport-1624993431: InProgress
# ......
# 2021-06-29 19:05:16 Starting - Preparing the instances for training.........
# 2021-06-29 19:06:36 Downloading - Downloading input data...
# 2021-06-29 19:07:16 Training - Training image download completed. Training in progress.
# 2021-06-29 19:07:16 Uploading - Uploading generated training model[2021-06-29 19:07:11.405 ip-10-2-232-112.ec2.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-06-29:19:07:11:INFO] Imported framework sagemaker_xgboost_container.training
# [2021-06-29:19:07:11:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2021-06-29:19:07:11:INFO] No GPUs detected (normal if no gpus installed)
# [2021-06-29:19:07:11:INFO] Running XGBoost Sagemaker in algorithm mode
# [2021-06-29:19:07:11:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:07:11:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:07:11:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:07:11:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:07:11:INFO] Single node training.
# [2021-06-29:19:07:11:INFO] Train matrix has 7620 rows and 13 columns
# [2021-06-29:19:07:11:INFO] Validation matrix has 3266 rows
# [0]#011train-rmse:3.90481#011validation-rmse:3.91500
# [1]#011train-rmse:3.52571#011validation-rmse:3.53473
# [2]#011train-rmse:3.18357#011validation-rmse:3.19135
# [3]#011train-rmse:2.87753#011validation-rmse:2.88396
# [4]#011train-rmse:2.60175#011validation-rmse:2.60792
# [5]#011train-rmse:2.35539#011validation-rmse:2.36057
# [6]#011train-rmse:2.13328#011validation-rmse:2.13766
# [7]#011train-rmse:1.93436#011validation-rmse:1.93815
# [8]#011train-rmse:1.75541#011validation-rmse:1.75955
# [9]#011train-rmse:1.59684#011validation-rmse:1.60086
# [10]#011train-rmse:1.45230#011validation-rmse:1.45613
# [11]#011train-rmse:1.32451#011validation-rmse:1.32875
# [12]#011train-rmse:1.21094#011validation-rmse:1.21528
# [13]#011train-rmse:1.10819#011validation-rmse:1.11280
# [118]#011train-rmse:0.24083#011validation-rmse:0.28954
# [119]#011train-rmse:0.24025#011validation-rmse:0.28945
# [120]#011train-rmse:0.23996#011validation-rmse:0.28938
# [121]#011train-rmse:0.23951#011validation-rmse:0.28926
# [122]#011train-rmse:0.23929#011validation-rmse:0.28921
# [123]#011train-rmse:0.23915#011validation-rmse:0.28911
# [124]#011train-rmse:0.23864#011validation-rmse:0.28879
# [125]#011train-rmse:0.23817#011validation-rmse:0.28861
# [126]#011train-rmse:0.23796#011validation-rmse:0.28842
# [127]#011train-rmse:0.23744#011validation-rmse:0.28851
# [128]#011train-rmse:0.23713#011validation-rmse:0.28845
# [129]#011train-rmse:0.23696#011validation-rmse:0.28839
# [130]#011train-rmse:0.23653#011validation-rmse:0.28820
# [131]#011train-rmse:0.23607#011validation-rmse:0.28809
# [132]#011train-rmse:0.23580#011validation-rmse:0.28810
# [133]#011train-rmse:0.23528#011validation-rmse:0.28788
# [134]#011train-rmse:0.23485#011validation-rmse:0.28795
# [135]#011train-rmse:0.23462#011validation-rmse:0.28789
# [136]#011train-rmse:0.23447#011validation-rmse:0.28780
# [137]#011train-rmse:0.23430#011validation-rmse:0.28773
# [138]#011train-rmse:0.23417#011validation-rmse:0.28769
# [139]#011train-rmse:0.23404#011validation-rmse:0.28766
# [140]#011train-rmse:0.23380#011validation-rmse:0.28770
# [141]#011train-rmse:0.23335#011validation-rmse:0.28762
# [142]#011train-rmse:0.23327#011validation-rmse:0.28762
# [143]#011train-rmse:0.23316#011validation-rmse:0.28758
# [144]#011train-rmse:0.23307#011validation-rmse:0.28758
# [145]#011train-rmse:0.23256#011validation-rmse:0.28730
# [146]#011train-rmse:0.23211#011validation-rmse:0.28700
# [147]#011train-rmse:0.23156#011validation-rmse:0.28691
# [148]#011train-rmse:0.23124#011validation-rmse:0.28682
# [149]#011train-rmse:0.23111#011validation-rmse:0.28681
# 2021-06-29 19:07:36 Completed - Training job completed
# Training seconds: 51
# Billable seconds: 18
# Managed Spot Training savings: 64.7%
# 'xgboost-bikerental-hyper-one-2021-06-29-19-03-51-772'

# %%
fit_model(jobSuffix="hyper-two", hyperParameters=hyperParametersTwo)
# Out:
# ***Job name: xgboost-bikerental-hyper-two***
# Checkpoint uri: s3://chandra-ml-sagemaker/bikerental-hyper/checkpoints/xgboost-bikerental-hyper-two
# Using XGBoost Container 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-2
# 2021-06-29 19:08:04 Starting - Starting the training job...
# 2021-06-29 19:08:29 Starting - Launching requested ML instancesProfilerReport-1624993684: InProgress
# ......
# 2021-06-29 19:09:30 Starting - Preparing the instances for training.........
# 2021-06-29 19:10:50 Downloading - Downloading input data...
# 2021-06-29 19:11:31 Training - Training image download completed. Training in progress..[2021-06-29 19:11:31.598 ip-10-0-175-221.ec2.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-06-29:19:11:31:INFO] Imported framework sagemaker_xgboost_container.training
# [2021-06-29:19:11:31:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2021-06-29:19:11:31:INFO] No GPUs detected (normal if no gpus installed)
# [2021-06-29:19:11:31:INFO] Running XGBoost Sagemaker in algorithm mode
# [2021-06-29:19:11:31:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:11:31:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:11:31:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:11:31:INFO] Determined delimiter of CSV input is ','
# [2021-06-29:19:11:31:INFO] Single node training.
# [2021-06-29:19:11:31:INFO] Train matrix has 7620 rows and 13 columns
# [2021-06-29:19:11:31:INFO] Validation matrix has 3266 rows
# [0]#011train-rmse:3.90281#011validation-rmse:3.91388
# [1]#011train-rmse:3.52097#011validation-rmse:3.53080
# [2]#011train-rmse:3.17794#011validation-rmse:3.18728
# [3]#011train-rmse:2.86951#011validation-rmse:2.87850
# [4]#011train-rmse:2.59216#011validation-rmse:2.60049
# [5]#011train-rmse:2.34263#011validation-rmse:2.35108
# [6]#011train-rmse:2.11799#011validation-rmse:2.12746
# [7]#011train-rmse:1.91517#011validation-rmse:1.92553
# [8]#011train-rmse:1.73415#011validation-rmse:1.74470
# [9]#011train-rmse:1.57176#011validation-rmse:1.58256
# [10]#011train-rmse:1.42448#011validation-rmse:1.43702
# [11]#011train-rmse:1.29415#011validation-rmse:1.30807
# [12]#011train-rmse:1.17542#011validation-rmse:1.19038
# [13]#011train-rmse:1.07054#011validation-rmse:1.08668
# [14]#011train-rmse:0.97598#011validation-rmse:0.99366
# [15]#011train-rmse:0.88975#011validation-rmse:0.90907
# [16]#011train-rmse:0.81411#011validation-rmse:0.83481
# [17]#011train-rmse:0.74665#011validation-rmse:0.76969
# [18]#011train-rmse:0.68600#011validation-rmse:0.71110
# [19]#011train-rmse:0.63019#011validation-rmse:0.65773
# [20]#011train-rmse:0.58103#011validation-rmse:0.61115
# [21]#011train-rmse:0.53729#011validation-rmse:0.56996
# [22]#011train-rmse:0.49862#011validation-rmse:0.53347
# [23]#011train-rmse:0.46481#011validation-rmse:0.50264
# [24]#011train-rmse:0.43512#011validation-rmse:0.47561
# [25]#011train-rmse:0.40832#011validation-rmse:0.45126
# [26]#011train-rmse:0.38597#011validation-rmse:0.43157
# [27]#011train-rmse:0.36458#011validation-rmse:0.41291
# [28]#011train-rmse:0.34589#011validation-rmse:0.39728
# [29]#011train-rmse:0.32970#011validation-rmse:0.38379
# [30]#011train-rmse:0.31444#011validation-rmse:0.37105
# [31]#011train-rmse:0.30256#011validation-rmse:0.36138
# [32]#011train-rmse:0.29161#011validation-rmse:0.35260
# [33]#011train-rmse:0.28311#011validation-rmse:0.34609
# [34]#011train-rmse:0.27395#011validation-rmse:0.33888
# [35]#011train-rmse:0.26715#011validation-rmse:0.33392
# [36]#011train-rmse:0.26018#011validation-rmse:0.32883
# [37]#011train-rmse:0.25485#011validation-rmse:0.32502
# [38]#011train-rmse:0.24981#011validation-rmse:0.32139
# [39]#011train-rmse:0.24493#011validation-rmse:0.31793
# [40]#011train-rmse:0.24060#011validation-rmse:0.31495
# [41]#011train-rmse:0.23731#011validation-rmse:0.31285
# [42]#011train-rmse:0.23409#011validation-rmse:0.31063
# [43]#011train-rmse:0.23146#011validation-rmse:0.30901
# [44]#011train-rmse:0.22884#011validation-rmse:0.30750
# [45]#011train-rmse:0.22635#011validation-rmse:0.30617
# [46]#011train-rmse:0.22417#011validation-rmse:0.30484
# [47]#011train-rmse:0.22189#011validation-rmse:0.30363
# [48]#011train-rmse:0.21948#011validation-rmse:0.30247
# [49]#011train-rmse:0.21671#011validation-rmse:0.30121
# [50]#011train-rmse:0.21478#011validation-rmse:0.30044
# [51]#011train-rmse:0.21326#011validation-rmse:0.30005
# [52]#011train-rmse:0.21137#011validation-rmse:0.29900
# [53]#011train-rmse:0.20945#011validation-rmse:0.29777
# [54]#011train-rmse:0.20827#011validation-rmse:0.29732
# [55]#011train-rmse:0.20605#011validation-rmse:0.29624
# [56]#011train-rmse:0.20502#011validation-rmse:0.29595
# [57]#011train-rmse:0.20397#011validation-rmse:0.29556
# [58]#011train-rmse:0.20214#011validation-rmse:0.29477
# [59]#011train-rmse:0.20044#011validation-rmse:0.29390
# [60]#011train-rmse:0.19890#011validation-rmse:0.29366
# [61]#011train-rmse:0.19839#011validation-rmse:0.29344
# [62]#011train-rmse:0.19785#011validation-rmse:0.29324
# [63]#011train-rmse:0.19702#011validation-rmse:0.29303
# [64]#011train-rmse:0.19639#011validation-rmse:0.29277
# [65]#011train-rmse:0.19528#011validation-rmse:0.29240
# [66]#011train-rmse:0.19471#011validation-rmse:0.29215
# [67]#011train-rmse:0.19400#011validation-rmse:0.29195
# [68]#011train-rmse:0.19271#011validation-rmse:0.29143
# [69]#011train-rmse:0.19155#011validation-rmse:0.29107
# [70]#011train-rmse:0.19090#011validation-rmse:0.29065
# [71]#011train-rmse:0.18985#011validation-rmse:0.29047
# [72]#011train-rmse:0.18945#011validation-rmse:0.29036
# [73]#011train-rmse:0.18837#011validation-rmse:0.29006
# [74]#011train-rmse:0.18778#011validation-rmse:0.28972
# [75]#011train-rmse:0.18745#011validation-rmse:0.28966
# [76]#011train-rmse:0.18639#011validation-rmse:0.28920
# [77]#011train-rmse:0.18555#011validation-rmse:0.28881
# [78]#011train-rmse:0.18521#011validation-rmse:0.28872
# [79]#011train-rmse:0.18426#011validation-rmse:0.28842
# [80]#011train-rmse:0.18377#011validation-rmse:0.28830
# [81]#011train-rmse:0.18255#011validation-rmse:0.28831
# [82]#011train-rmse:0.18207#011validation-rmse:0.28829
# [83]#011train-rmse:0.18166#011validation-rmse:0.28823
# [84]#011train-rmse:0.18128#011validation-rmse:0.28813
# [85]#011train-rmse:0.18003#011validation-rmse:0.28760
# [86]#011train-rmse:0.17982#011validation-rmse:0.28753
# [87]#011train-rmse:0.17916#011validation-rmse:0.28733
# [88]#011train-rmse:0.17829#011validation-rmse:0.28726
# [89]#011train-rmse:0.17822#011validation-rmse:0.28725
# [90]#011train-rmse:0.17734#011validation-rmse:0.28734
# [91]#011train-rmse:0.17668#011validation-rmse:0.28732
# [92]#011train-rmse:0.17603#011validation-rmse:0.28731
# [93]#011train-rmse:0.17574#011validation-rmse:0.28711
# [94]#011train-rmse:0.17550#011validation-rmse:0.28716
# [95]#011train-rmse:0.17519#011validation-rmse:0.28707
# [96]#011train-rmse:0.17461#011validation-rmse:0.28701
# [97]#011train-rmse:0.17435#011validation-rmse:0.28695
# [98]#011train-rmse:0.17349#011validation-rmse:0.28685
# [99]#011train-rmse:0.17281#011validation-rmse:0.28662
# [100]#011train-rmse:0.17194#011validation-rmse:0.28654
# [101]#011train-rmse:0.17091#011validation-rmse:0.28644
# [102]#011train-rmse:0.17041#011validation-rmse:0.28641
# [103]#011train-rmse:0.16931#011validation-rmse:0.28653
# [104]#011train-rmse:0.16808#011validation-rmse:0.28654
# [105]#011train-rmse:0.16709#011validation-rmse:0.28674
# [106]#011train-rmse:0.16595#011validation-rmse:0.28660
# [107]#011train-rmse:0.16566#011validation-rmse:0.28646
# [108]#011train-rmse:0.16468#011validation-rmse:0.28628
# [109]#011train-rmse:0.16429#011validation-rmse:0.28620
# [110]#011train-rmse:0.16335#011validation-rmse:0.28607
# [111]#011train-rmse:0.16323#011validation-rmse:0.28602
# [112]#011train-rmse:0.16241#011validation-rmse:0.28584
# [113]#011train-rmse:0.16197#011validation-rmse:0.28563
# [114]#011train-rmse:0.16106#011validation-rmse:0.28547
# [115]#011train-rmse:0.16054#011validation-rmse:0.28539
# [116]#011train-rmse:0.15968#011validation-rmse:0.28553
# [117]#011train-rmse:0.15928#011validation-rmse:0.28565
# [118]#011train-rmse:0.15916#011validation-rmse:0.28567
# [119]#011train-rmse:0.15883#011validation-rmse:0.28567
# [120]#011train-rmse:0.15822#011validation-rmse:0.28586
# [121]#011train-rmse:0.15772#011validation-rmse:0.28577
# [122]#011train-rmse:0.15689#011validation-rmse:0.28566
# [123]#011train-rmse:0.15636#011validation-rmse:0.28562
# [124]#011train-rmse:0.15568#011validation-rmse:0.28549
# [125]#011train-rmse:0.15551#011validation-rmse:0.28550
# [126]#011train-rmse:0.15496#011validation-rmse:0.28544
# [127]#011train-rmse:0.15406#011validation-rmse:0.28545
# [128]#011train-rmse:0.15315#011validation-rmse:0.28526
# [129]#011train-rmse:0.15225#011validation-rmse:0.28503
# [130]#011train-rmse:0.15172#011validation-rmse:0.28493
# [131]#011train-rmse:0.15157#011validation-rmse:0.28486
# [132]#011train-rmse:0.15141#011validation-rmse:0.28484
# [133]#011train-rmse:0.15097#011validation-rmse:0.28472
# [134]#011train-rmse:0.15080#011validation-rmse:0.28471
# [135]#011train-rmse:0.15053#011validation-rmse:0.28470
# [136]#011train-rmse:0.15010#011validation-rmse:0.28462
# [137]#011train-rmse:0.14965#011validation-rmse:0.28443
# [138]#011train-rmse:0.14937#011validation-rmse:0.28440
# [139]#011train-rmse:0.14871#011validation-rmse:0.28438
# [140]#011train-rmse:0.14824#011validation-rmse:0.28437
# [141]#011train-rmse:0.14820#011validation-rmse:0.28436
# [142]#011train-rmse:0.14812#011validation-rmse:0.28443
# [143]#011train-rmse:0.14802#011validation-rmse:0.28444
# [144]#011train-rmse:0.14758#011validation-rmse:0.28438
# [145]#011train-rmse:0.14694#011validation-rmse:0.28430
# [146]#011train-rmse:0.14634#011validation-rmse:0.28430
# [147]#011train-rmse:0.14596#011validation-rmse:0.28428
# [148]#011train-rmse:0.14543#011validation-rmse:0.28420
# [149]#011train-rmse:0.14522#011validation-rmse:0.28423
# [150]#011train-rmse:0.14462#011validation-rmse:0.28417
# [151]#011train-rmse:0.14426#011validation-rmse:0.28411
# [152]#011train-rmse:0.14404#011validation-rmse:0.28415
# [153]#011train-rmse:0.14325#011validation-rmse:0.28401
# [154]#011train-rmse:0.14289#011validation-rmse:0.28399
# [155]#011train-rmse:0.14271#011validation-rmse:0.28394
# [156]#011train-rmse:0.14260#011validation-rmse:0.28402
# [157]#011train-rmse:0.14198#011validation-rmse:0.28390
# [158]#011train-rmse:0.14183#011validation-rmse:0.28393
# [159]#011train-rmse:0.14143#011validation-rmse:0.28396
# [160]#011train-rmse:0.14089#011validation-rmse:0.28388
# [161]#011train-rmse:0.14044#011validation-rmse:0.28378
# [162]#011train-rmse:0.14000#011validation-rmse:0.28374
# [163]#011train-rmse:0.13967#011validation-rmse:0.28372
# [164]#011train-rmse:0.13932#011validation-rmse:0.28375
# [165]#011train-rmse:0.13877#011validation-rmse:0.28377
# [166]#011train-rmse:0.13816#011validation-rmse:0.28373
# [167]#011train-rmse:0.13800#011validation-rmse:0.28374
# [168]#011train-rmse:0.13779#011validation-rmse:0.28377
# [169]#011train-rmse:0.13704#011validation-rmse:0.28359
# [170]#011train-rmse:0.13696#011validation-rmse:0.28362
# [171]#011train-rmse:0.13657#011validation-rmse:0.28357
# [172]#011train-rmse:0.13635#011validation-rmse:0.28354
# [173]#011train-rmse:0.13588#011validation-rmse:0.28362
# [174]#011train-rmse:0.13566#011validation-rmse:0.28363
# [175]#011train-rmse:0.13537#011validation-rmse:0.28361
# [176]#011train-rmse:0.13507#011validation-rmse:0.28357
# [177]#011train-rmse:0.13435#011validation-rmse:0.28352
# [178]#011train-rmse:0.13376#011validation-rmse:0.28358
# [179]#011train-rmse:0.13326#011validation-rmse:0.28358
# [180]#011train-rmse:0.13283#011validation-rmse:0.28358
# [181]#011train-rmse:0.13246#011validation-rmse:0.28357
# [182]#011train-rmse:0.13210#011validation-rmse:0.28378
# [183]#011train-rmse:0.13183#011validation-rmse:0.28380
# [184]#011train-rmse:0.13169#011validation-rmse:0.28377
# [185]#011train-rmse:0.13157#011validation-rmse:0.28376
# [186]#011train-rmse:0.13134#011validation-rmse:0.28379
# [187]#011train-rmse:0.13112#011validation-rmse:0.28386
# [188]#011train-rmse:0.13054#011validation-rmse:0.28386
# [189]#011train-rmse:0.13016#011validation-rmse:0.28388
# [190]#011train-rmse:0.12981#011validation-rmse:0.28377
# [191]#011train-rmse:0.12962#011validation-rmse:0.28376
# [192]#011train-rmse:0.12945#011validation-rmse:0.28376
# [193]#011train-rmse:0.12932#011validation-rmse:0.28378
# [194]#011train-rmse:0.12924#011validation-rmse:0.28375
# [195]#011train-rmse:0.12878#011validation-rmse:0.28379
# [196]#011train-rmse:0.12829#011validation-rmse:0.28375
# [197]#011train-rmse:0.12776#011validation-rmse:0.28371
# [198]#011train-rmse:0.12728#011validation-rmse:0.28363
# [199]#011train-rmse:0.12689#011validation-rmse:0.28364
# 2021-06-29 19:11:50 Uploading - Uploading generated training model
# 2021-06-29 19:11:50 Completed - Training job completed
# Training seconds: 62
# Billable seconds: 22
# Managed Spot Training savings: 64.5%
# 'xgboost-bikerental-hyper-two-2021-06-29-19-08-04-688'
