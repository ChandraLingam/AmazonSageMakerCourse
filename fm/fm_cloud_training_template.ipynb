# %%
import numpy as np
import pandas as pd

# Define IAM role
import boto3
import re
import sagemaker
from sagemaker import get_execution_role

# SageMaker SDK Documentation: http://sagemaker.readthedocs.io/en/latest/estimators.html

# %% [markdown]
# ## Upload Data to S3

# %%
bucket_name = 'chandra-ml-sagemaker'
training_file_key = 'movie/user_movie_train.recordio'
test_file_key = 'movie/user_movie_test.recordio'

s3_model_output_location = r's3://{0}/movie/model'.format(bucket_name)
s3_training_file_location = r's3://{0}/{1}'.format(bucket_name,training_file_key)
s3_test_file_location = r's3://{0}/{1}'.format(bucket_name,test_file_key)

# %%
print(s3_model_output_location)
print(s3_training_file_location)
print(s3_test_file_location)
# Out:
# s3://chandra-ml-sagemaker/movie/model
# s3://chandra-ml-sagemaker/movie/user_movie_train.recordio
# s3://chandra-ml-sagemaker/movie/user_movie_test.recordio

# %%
# Write and Reading from S3 is just as easy
# files are referred as objects in S3.  
# file name is referred as key name in S3
# Files stored in S3 are automatically replicated across 3 different availability zones 
# in the region where the bucket was created.

# http://boto3.readthedocs.io/en/latest/guide/s3.html
def write_to_s3(filename, bucket, key):
    with open(filename,'rb') as f: # Read in binary mode
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(f)

# %%
write_to_s3(r'ml-latest-small/user_movie_train.recordio',bucket_name,training_file_key)

# %%
write_to_s3(r'ml-latest-small/user_movie_test.recordio',bucket_name,test_file_key)

# %% [markdown]
# ## Training Algorithm Docker Image
# ### AWS Maintains a separate image for every region and algorithm

# %%
# Registry Path for algorithms provided by SageMaker
#  https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html
containers = {'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/factorization-machines:latest',
              'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/factorization-machines:latest',
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/factorization-machines:latest',
              'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/factorization-machines:latest'}

# %%
role = get_execution_role()

# %%
# This role contains the permissions needed to train, deploy models
# SageMaker Service is trusted to assume this role
print(role)
# Out:
# arn:aws:iam::144943967277:role/service-role/AmazonSageMaker-ExecutionRole-20180311T102769

# %% [markdown]
# ## Build Model

# %%
sess = sagemaker.Session()

# %%
# Access appropriate algorithm container image
#  Specify how many instances to use for distributed training and what type of machine to use
#  Finally, specify where the trained model artifacts needs to be stored
#   Reference: http://sagemaker.readthedocs.io/en/latest/estimators.html
#    Optionally, give a name to the training job using base_job_name

estimator = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m4.xlarge',
                                       output_path=s3_model_output_location,
                                       sagemaker_session=sess,
                                       base_job_name ='fm-movie-v2')

# %%
# Specify hyper parameters that appropriate for the training algorithm
# Sparse Matrix dimension: 100004, 9737
estimator.set_hyperparameters(feature_dim=9737,
                              num_factors=8,
                              predictor_type='regressor', 
                              mini_batch_size=1000,
                              epochs=100)

# %%
estimator.hyperparameters()
# Out:
# {'epochs': 100,
#  'feature_dim': 9737,
#  'mini_batch_size': 1000,
#  'num_factors': 8,
#  'predictor_type': 'regressor'}

# %% [markdown]
# ### Train the model

# %%
# XGBoost supports "train", "validation" channels
# Reference: Supported channels by algorithm
#   https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html
estimator.fit({'train':s3_training_file_location, 'test': s3_test_file_location})
# Out:
# INFO:sagemaker:Creating training-job with name: fm-movie-v2-2018-05-31-00-22-13-174
# .......................
# Docker entrypoint called with argument(s): train
# [05/31/2018 00:25:52 INFO 140523443300160] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [05/31/2018 00:25:52 INFO 140523443300160] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'9737', u'mini_batch_size': u'1000', u'predictor_type': u'regressor', u'num_factors': u'8'}
# [05/31/2018 00:25:52 INFO 140523443300160] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'100', u'feature_dim': u'9737', u'num_factors': u'8', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'regressor', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [05/31/2018 00:25:52 WARNING 140523443300160] Loggers have already been setup.
# [05/31/2018 00:25:52 INFO 140523443300160] Using default worker.
# [05/31/2018 00:25:52 INFO 140523443300160] nvidia-smi took: 0.0251700878143 secs to identify 0 gpus
# [05/31/2018 00:25:52 INFO 140523443300160] Number of GPUs being used: 0
# [05/31/2018 00:25:52 INFO 140523443300160] [Sparse network] Building a sparse network.
# [05/31/2018 00:25:52 INFO 140523443300160] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 39.63494300842285, "sum": 39.63494300842285, "min": 39.63494300842285}}, "EndTime": 1527726352.953964, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726352.886505}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1527726352.954165, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726352.954099}
#
# [00:25:52] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.200266.0/RHEL5_64/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [00:25:52] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.200266.0/RHEL5_64/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [05/31/2018 00:25:53 INFO 140523443300160] #quality_metric: host=algo-1, epoch=0, batch=0 train rmse <loss>=3.67641647341
# [05/31/2018 00:25:53 INFO 140523443300160] #quality_metric: host=algo-1, epoch=0, train rmse <loss>=1.87471988399
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "update.time": {"count": 1, "max": 472.99814224243164, "sum": 472.99814224243164, "min": 472.99814224243164}}, "EndTime": 1527726353.427432, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726352.954039}
#
# [05/31/2018 00:25:53 INFO 140523443300160] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 72, "sum": 72.0, "min": 72}, "Total Records Seen": {"count": 1, "max": 71002, "sum": 71002.0, "min": 71002}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1527726353.427826, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1527726353.427767}
#
# [05/31/2018 00:25:53 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=147828.249274 records/second
# [05/31/2018 00:25:53 INFO 140523443300160] #quality_metric: host=algo-1, epoch=1, batch=0 train rmse <loss>=1.08417060619
# [05/31/2018 00:25:53 INFO 140523443300160] #quality_metric: host=algo-1, epoch=1, train rmse <loss>=1.11956424779
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 420.61614990234375, "sum": 420.61614990234375, "min": 420.61614990234375}}, "EndTime": 1527726353.848933, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726353.427514}
#
# [05/31/2018 00:25:53 INFO 140523443300160] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 143, "sum": 143.0, "min": 143}, "Total Records Seen": {"count": 1, "max": 141004, "sum": 141004.0, "min": 141004}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1527726353.849242, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 1}, "StartTime": 1527726353.849197}
#
# [05/31/2018 00:25:53 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=166212.749054 records/second
# [05/31/2018 00:25:53 INFO 140523443300160] #quality_metric: host=algo-1, epoch=2, batch=0 train rmse <loss>=1.07172437672
# [05/31/2018 00:25:54 INFO 140523443300160] #quality_metric: host=algo-1, epoch=2, train rmse <loss>=1.1095351474
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 408.7679386138916, "sum": 408.7679386138916, "min": 408.7679386138916}}, "EndTime": 1527726354.258436, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726353.849022}
#
# [05/31/2018 00:25:54 INFO 140523443300160] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 214, "sum": 214.0, "min": 214}, "Total Records Seen": {"count": 1, "max": 211006, "sum": 211006.0, "min": 211006}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1527726354.258703, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 2}, "StartTime": 1527726354.258648}
#
# [05/31/2018 00:25:54 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=171086.250391 records/second
# [05/31/2018 00:25:54 INFO 140523443300160] #quality_metric: host=algo-1, epoch=3, batch=0 train rmse <loss>=1.06016148903
# [05/31/2018 00:25:54 INFO 140523443300160] #quality_metric: host=algo-1, epoch=3, train rmse <loss>=1.09804945638
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 372.96605110168457, "sum": 372.96605110168457, "min": 372.96605110168457}}, "EndTime": 1527726354.63217, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726354.258509}
#
# [05/31/2018 00:25:54 INFO 140523443300160] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 285, "sum": 285.0, "min": 285}, "Total Records Seen": {"count": 1, "max": 281008, "sum": 281008.0, "min": 281008}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1527726354.632438, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 3}, "StartTime": 1527726354.632382}
#
# [05/31/2018 00:25:54 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=187461.360422 records/second
# [05/31/2018 00:25:54 INFO 140523443300160] #quality_metric: host=algo-1, epoch=4, batch=0 train rmse <loss>=1.04845234481
# [05/31/2018 00:25:55 INFO 140523443300160] #quality_metric: host=algo-1, epoch=4, train rmse <loss>=1.08657634553
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 400.1901149749756, "sum": 400.1901149749756, "min": 400.1901149749756}}, "EndTime": 1527726355.033005, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726354.632241}
#
# [05/31/2018 00:25:55 INFO 140523443300160] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 356, "sum": 356.0, "min": 356}, "Total Records Seen": {"count": 1, "max": 351010, "sum": 351010.0, "min": 351010}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1527726355.033287, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 4}, "StartTime": 1527726355.033228}
#
# [05/31/2018 00:25:55 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=174718.884197 records/second
# [05/31/2018 00:25:55 INFO 140523443300160] #quality_metric: host=algo-1, epoch=5, batch=0 train rmse <loss>=1.03698629507
# [05/31/2018 00:25:55 INFO 140523443300160] #quality_metric: host=algo-1, epoch=5, train rmse <loss>=1.07556060837
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 370.9681034088135, "sum": 370.9681034088135, "min": 370.9681034088135}}, "EndTime": 1527726355.405925, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726355.033076}
#
# [05/31/2018 00:25:55 INFO 140523443300160] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 427, "sum": 427.0, "min": 427}, "Total Records Seen": {"count": 1, "max": 421012, "sum": 421012.0, "min": 421012}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1527726355.406211, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 5}, "StartTime": 1527726355.406152}
#
# [05/31/2018 00:25:55 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=188493.099048 records/second
# [05/31/2018 00:25:55 INFO 140523443300160] #quality_metric: host=algo-1, epoch=6, batch=0 train rmse <loss>=1.02601149358
# [05/31/2018 00:25:55 INFO 140523443300160] #quality_metric: host=algo-1, epoch=6, train rmse <loss>=1.06520525481
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 354.6910285949707, "sum": 354.6910285949707, "min": 354.6910285949707}}, "EndTime": 1527726355.761234, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726355.405995}
#
# [05/31/2018 00:25:55 INFO 140523443300160] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 498, "sum": 498.0, "min": 498}, "Total Records Seen": {"count": 1, "max": 491014, "sum": 491014.0, "min": 491014}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1527726355.761502, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 6}, "StartTime": 1527726355.761447}
#
# [05/31/2018 00:25:55 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=197158.267084 records/second
# [05/31/2018 00:25:55 INFO 140523443300160] #quality_metric: host=algo-1, epoch=7, batch=0 train rmse <loss>=1.01568749808
# [05/31/2018 00:25:56 INFO 140523443300160] #quality_metric: host=algo-1, epoch=7, train rmse <loss>=1.05559682655
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 380.4929256439209, "sum": 380.4929256439209, "min": 380.4929256439209}}, "EndTime": 1527726356.142333, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726355.761304}
#
# [05/31/2018 00:25:56 INFO 140523443300160] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 569, "sum": 569.0, "min": 569}, "Total Records Seen": {"count": 1, "max": 561016, "sum": 561016.0, "min": 561016}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1527726356.142591, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 7}, "StartTime": 1527726356.142535}
#
# [05/31/2018 00:25:56 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=183794.48535 records/second
# [05/31/2018 00:25:56 INFO 140523443300160] #quality_metric: host=algo-1, epoch=8, batch=0 train rmse <loss>=1.0060917359
# [05/31/2018 00:25:56 INFO 140523443300160] #quality_metric: host=algo-1, epoch=8, train rmse <loss>=1.04675410045
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 370.5430030822754, "sum": 370.5430030822754, "min": 370.5430030822754}}, "EndTime": 1527726356.513535, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726356.142402}
#
# [05/31/2018 00:25:56 INFO 140523443300160] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 640, "sum": 640.0, "min": 640}, "Total Records Seen": {"count": 1, "max": 631018, "sum": 631018.0, "min": 631018}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1527726356.513819, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 8}, "StartTime": 1527726356.513763}
#
# [05/31/2018 00:25:56 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=188698.434104 records/second
# [05/31/2018 00:25:56 INFO 140523443300160] #quality_metric: host=algo-1, epoch=9, batch=0 train rmse <loss>=0.99724290331
# [05/31/2018 00:25:56 INFO 140523443300160] #quality_metric: host=algo-1, epoch=9, train rmse <loss>=1.03865678798
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 361.346960067749, "sum": 361.346960067749, "min": 361.346960067749}}, "EndTime": 1527726356.875504, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726356.513609}
#
# [05/31/2018 00:25:56 INFO 140523443300160] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 711, "sum": 711.0, "min": 711}, "Total Records Seen": {"count": 1, "max": 701020, "sum": 701020.0, "min": 701020}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1527726356.875761, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 9}, "StartTime": 1527726356.875705}
#
# [05/31/2018 00:25:56 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=193519.975935 records/second
# [05/31/2018 00:25:56 INFO 140523443300160] #quality_metric: host=algo-1, epoch=10, batch=0 train rmse <loss>=0.989122850647
# [05/31/2018 00:25:57 INFO 140523443300160] #quality_metric: host=algo-1, epoch=10, train rmse <loss>=1.03126288613
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 385.7131004333496, "sum": 385.7131004333496, "min": 385.7131004333496}}, "EndTime": 1527726357.262927, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726356.875573}
#
# [05/31/2018 00:25:57 INFO 140523443300160] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 782, "sum": 782.0, "min": 782}, "Total Records Seen": {"count": 1, "max": 771022, "sum": 771022.0, "min": 771022}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1527726357.263184, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 10}, "StartTime": 1527726357.263126}
#
# [05/31/2018 00:25:57 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=181310.038359 records/second
# [05/31/2018 00:25:57 INFO 140523443300160] #quality_metric: host=algo-1, epoch=11, batch=0 train rmse <loss>=0.981691499751
# [05/31/2018 00:25:57 INFO 140523443300160] #quality_metric: host=algo-1, epoch=11, train rmse <loss>=1.02451911929
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 378.1149387359619, "sum": 378.1149387359619, "min": 378.1149387359619}}, "EndTime": 1527726357.641603, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726357.262997}
#
# [05/31/2018 00:25:57 INFO 140523443300160] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 853, "sum": 853.0, "min": 853}, "Total Records Seen": {"count": 1, "max": 841024, "sum": 841024.0, "min": 841024}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1527726357.641874, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 11}, "StartTime": 1527726357.641797}
#
# [05/31/2018 00:25:57 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=184938.041251 records/second
# [05/31/2018 00:25:57 INFO 140523443300160] #quality_metric: host=algo-1, epoch=12, batch=0 train rmse <loss>=0.974897267725
# [05/31/2018 00:25:58 INFO 140523443300160] #quality_metric: host=algo-1, epoch=12, train rmse <loss>=1.01836738871
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 369.6098327636719, "sum": 369.6098327636719, "min": 369.6098327636719}}, "EndTime": 1527726358.011848, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726357.641669}
#
# [05/31/2018 00:25:58 INFO 140523443300160] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 924, "sum": 924.0, "min": 924}, "Total Records Seen": {"count": 1, "max": 911026, "sum": 911026.0, "min": 911026}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1527726358.012109, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 12}, "StartTime": 1527726358.012053}
#
# [05/31/2018 00:25:58 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=189196.116071 records/second
# [05/31/2018 00:25:58 INFO 140523443300160] #quality_metric: host=algo-1, epoch=13, batch=0 train rmse <loss>=0.968683843507
# [05/31/2018 00:25:58 INFO 140523443300160] #quality_metric: host=algo-1, epoch=13, train rmse <loss>=1.01274910232
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 382.61890411376953, "sum": 382.61890411376953, "min": 382.61890411376953}}, "EndTime": 1527726358.39508, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726358.01192}
#
# [05/31/2018 00:25:58 INFO 140523443300160] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 995, "sum": 995.0, "min": 995}, "Total Records Seen": {"count": 1, "max": 981028, "sum": 981028.0, "min": 981028}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1527726358.395365, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 13}, "StartTime": 1527726358.395308}
#
# [05/31/2018 00:25:58 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=182756.626489 records/second
# [05/31/2018 00:25:58 INFO 140523443300160] #quality_metric: host=algo-1, epoch=14, batch=0 train rmse <loss>=0.962994463848
# [05/31/2018 00:25:58 INFO 140523443300160] #quality_metric: host=algo-1, epoch=14, train rmse <loss>=1.00760775784
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 370.32413482666016, "sum": 370.32413482666016, "min": 370.32413482666016}}, "EndTime": 1527726358.766129, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726358.395157}
#
# [05/31/2018 00:25:58 INFO 140523443300160] #progress_metric: host=algo-1, completed 15 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1066, "sum": 1066.0, "min": 1066}, "Total Records Seen": {"count": 1, "max": 1051030, "sum": 1051030.0, "min": 1051030}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1527726358.766383, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 14}, "StartTime": 1527726358.76633}
#
# [05/31/2018 00:25:58 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=188847.475701 records/second
# [05/31/2018 00:25:58 INFO 140523443300160] #quality_metric: host=algo-1, epoch=15, batch=0 train rmse <loss>=0.957774360731
# [05/31/2018 00:25:59 INFO 140523443300160] #quality_metric: host=algo-1, epoch=15, train rmse <loss>=1.00289045575
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 363.73114585876465, "sum": 363.73114585876465, "min": 363.73114585876465}}, "EndTime": 1527726359.130419, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726358.766199}
#
# [05/31/2018 00:25:59 INFO 140523443300160] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1137, "sum": 1137.0, "min": 1137}, "Total Records Seen": {"count": 1, "max": 1121032, "sum": 1121032.0, "min": 1121032}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1527726359.130706, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1527726359.130647}
#
# [05/31/2018 00:25:59 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=192232.937668 records/second
# [05/31/2018 00:25:59 INFO 140523443300160] #quality_metric: host=algo-1, epoch=16, batch=0 train rmse <loss>=0.952972676097
# [05/31/2018 00:25:59 INFO 140523443300160] #quality_metric: host=algo-1, epoch=16, train rmse <loss>=0.998548875166
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 372.1468448638916, "sum": 372.1468448638916, "min": 372.1468448638916}}, "EndTime": 1527726359.503407, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726359.130492}
#
# [05/31/2018 00:25:59 INFO 140523443300160] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1208, "sum": 1208.0, "min": 1208}, "Total Records Seen": {"count": 1, "max": 1191034, "sum": 1191034.0, "min": 1191034}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1527726359.504022, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1527726359.503959}
#
# [05/31/2018 00:25:59 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=187546.737336 records/second
# [05/31/2018 00:25:59 INFO 140523443300160] #quality_metric: host=algo-1, epoch=17, batch=0 train rmse <loss>=0.948542969321
# [05/31/2018 00:25:59 INFO 140523443300160] #quality_metric: host=algo-1, epoch=17, train rmse <loss>=0.994539478404
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 370.1469898223877, "sum": 370.1469898223877, "min": 370.1469898223877}}, "EndTime": 1527726359.875507, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726359.503546}
#
# [05/31/2018 00:25:59 INFO 140523443300160] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1279, "sum": 1279.0, "min": 1279}, "Total Records Seen": {"count": 1, "max": 1261036, "sum": 1261036.0, "min": 1261036}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1527726359.87579, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1527726359.875734}
#
# [05/31/2018 00:25:59 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=188914.305224 records/second
# [05/31/2018 00:25:59 INFO 140523443300160] #quality_metric: host=algo-1, epoch=18, batch=0 train rmse <loss>=0.944443492615
# [05/31/2018 00:26:00 INFO 140523443300160] #quality_metric: host=algo-1, epoch=18, train rmse <loss>=0.990823515999
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 384.55700874328613, "sum": 384.55700874328613, "min": 384.55700874328613}}, "EndTime": 1527726360.260952, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726359.875579}
#
# [05/31/2018 00:26:00 INFO 140523443300160] #progress_metric: host=algo-1, completed 19 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1350, "sum": 1350.0, "min": 1350}, "Total Records Seen": {"count": 1, "max": 1331038, "sum": 1331038.0, "min": 1331038}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 20, "sum": 20.0, "min": 20}}, "EndTime": 1527726360.261259, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 18}, "StartTime": 1527726360.2612}
#
# [05/31/2018 00:26:00 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=181739.42211 records/second
# [05/31/2018 00:26:00 INFO 140523443300160] #quality_metric: host=algo-1, epoch=19, batch=0 train rmse <loss>=0.940637198841
# [05/31/2018 00:26:00 INFO 140523443300160] #quality_metric: host=algo-1, epoch=19, train rmse <loss>=0.987366904139
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 380.7971477508545, "sum": 380.7971477508545, "min": 380.7971477508545}}, "EndTime": 1527726360.643667, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726360.261032}
#
# [05/31/2018 00:26:00 INFO 140523443300160] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1421, "sum": 1421.0, "min": 1421}, "Total Records Seen": {"count": 1, "max": 1401040, "sum": 1401040.0, "min": 1401040}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 21, "sum": 21.0, "min": 21}}, "EndTime": 1527726360.643923, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 19}, "StartTime": 1527726360.643868}
#
# [05/31/2018 00:26:00 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=183652.276005 records/second
# [05/31/2018 00:26:00 INFO 140523443300160] #quality_metric: host=algo-1, epoch=20, batch=0 train rmse <loss>=0.937091317172
# [05/31/2018 00:26:01 INFO 140523443300160] #quality_metric: host=algo-1, epoch=20, train rmse <loss>=0.984139720967
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 375.8280277252197, "sum": 375.8280277252197, "min": 375.8280277252197}}, "EndTime": 1527726361.020161, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726360.643736}
#
# [05/31/2018 00:26:01 INFO 140523443300160] #progress_metric: host=algo-1, completed 21 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1492, "sum": 1492.0, "min": 1492}, "Total Records Seen": {"count": 1, "max": 1471042, "sum": 1471042.0, "min": 1471042}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 22, "sum": 22.0, "min": 22}}, "EndTime": 1527726361.020451, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 20}, "StartTime": 1527726361.020392}
#
# [05/31/2018 00:26:01 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=186051.813095 records/second
# [05/31/2018 00:26:01 INFO 140523443300160] #quality_metric: host=algo-1, epoch=21, batch=0 train rmse <loss>=0.933777309361
# [05/31/2018 00:26:01 INFO 140523443300160] #quality_metric: host=algo-1, epoch=21, train rmse <loss>=0.981115945441
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 530.5800437927246, "sum": 530.5800437927246, "min": 530.5800437927246}}, "EndTime": 1527726361.551349, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726361.020235}
#
# [05/31/2018 00:26:01 INFO 140523443300160] #progress_metric: host=algo-1, completed 22 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1563, "sum": 1563.0, "min": 1563}, "Total Records Seen": {"count": 1, "max": 1541044, "sum": 1541044.0, "min": 1541044}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 23, "sum": 23.0, "min": 23}}, "EndTime": 1527726361.551859, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 21}, "StartTime": 1527726361.551759}
#
# [05/31/2018 00:26:01 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=131769.949007 records/second
# [05/31/2018 00:26:01 INFO 140523443300160] #quality_metric: host=algo-1, epoch=22, batch=0 train rmse <loss>=0.930670009982
# [05/31/2018 00:26:02 INFO 140523443300160] #quality_metric: host=algo-1, epoch=22, train rmse <loss>=0.978272790205
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 533.5428714752197, "sum": 533.5428714752197, "min": 533.5428714752197}}, "EndTime": 1527726362.087104, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726361.551453}
#
# [05/31/2018 00:26:02 INFO 140523443300160] #progress_metric: host=algo-1, completed 23 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1634, "sum": 1634.0, "min": 1634}, "Total Records Seen": {"count": 1, "max": 1611046, "sum": 1611046.0, "min": 1611046}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 24, "sum": 24.0, "min": 24}}, "EndTime": 1527726362.087418, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 22}, "StartTime": 1527726362.087359}
#
# [05/31/2018 00:26:02 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=131092.833802 records/second
# [05/31/2018 00:26:02 INFO 140523443300160] #quality_metric: host=algo-1, epoch=23, batch=0 train rmse <loss>=0.927747615037
# [05/31/2018 00:26:02 INFO 140523443300160] #quality_metric: host=algo-1, epoch=23, train rmse <loss>=0.975590721597
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 474.672794342041, "sum": 474.672794342041, "min": 474.672794342041}}, "EndTime": 1527726362.562564, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726362.087182}
#
# [05/31/2018 00:26:02 INFO 140523443300160] #progress_metric: host=algo-1, completed 24 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1705, "sum": 1705.0, "min": 1705}, "Total Records Seen": {"count": 1, "max": 1681048, "sum": 1681048.0, "min": 1681048}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 25, "sum": 25.0, "min": 25}}, "EndTime": 1527726362.562861, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 23}, "StartTime": 1527726362.562808}
#
# [05/31/2018 00:26:02 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=147345.001078 records/second
# [05/31/2018 00:26:02 INFO 140523443300160] #quality_metric: host=algo-1, epoch=24, batch=0 train rmse <loss>=0.924990993147
# [05/31/2018 00:26:02 INFO 140523443300160] #quality_metric: host=algo-1, epoch=24, train rmse <loss>=0.973052638027
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 381.96611404418945, "sum": 381.96611404418945, "min": 381.96611404418945}}, "EndTime": 1527726362.945203, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726362.56265}
#
# [05/31/2018 00:26:02 INFO 140523443300160] #progress_metric: host=algo-1, completed 25 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1776, "sum": 1776.0, "min": 1776}, "Total Records Seen": {"count": 1, "max": 1751050, "sum": 1751050.0, "min": 1751050}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 26, "sum": 26.0, "min": 26}}, "EndTime": 1527726362.94546, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 24}, "StartTime": 1527726362.945403}
#
# [05/31/2018 00:26:02 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=183087.459176 records/second
# [05/31/2018 00:26:02 INFO 140523443300160] #quality_metric: host=algo-1, epoch=25, batch=0 train rmse <loss>=0.922383235168
# [05/31/2018 00:26:03 INFO 140523443300160] #quality_metric: host=algo-1, epoch=25, train rmse <loss>=0.970643629551
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 364.49408531188965, "sum": 364.49408531188965, "min": 364.49408531188965}}, "EndTime": 1527726363.310267, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726362.945275}
#
# [05/31/2018 00:26:03 INFO 140523443300160] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1847, "sum": 1847.0, "min": 1847}, "Total Records Seen": {"count": 1, "max": 1821052, "sum": 1821052.0, "min": 1821052}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 27, "sum": 27.0, "min": 27}}, "EndTime": 1527726363.310555, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 25}, "StartTime": 1527726363.310496}
#
# [05/31/2018 00:26:03 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=191832.032678 records/second
# [05/31/2018 00:26:03 INFO 140523443300160] #quality_metric: host=algo-1, epoch=26, batch=0 train rmse <loss>=0.919909816136
# [05/31/2018 00:26:03 INFO 140523443300160] #quality_metric: host=algo-1, epoch=26, train rmse <loss>=0.968350917698
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 387.8011703491211, "sum": 387.8011703491211, "min": 387.8011703491211}}, "EndTime": 1527726363.698734, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726363.310341}
#
# [05/31/2018 00:26:03 INFO 140523443300160] #progress_metric: host=algo-1, completed 27 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1918, "sum": 1918.0, "min": 1918}, "Total Records Seen": {"count": 1, "max": 1891054, "sum": 1891054.0, "min": 1891054}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 28, "sum": 28.0, "min": 28}}, "EndTime": 1527726363.699024, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 26}, "StartTime": 1527726363.69897}
#
# [05/31/2018 00:26:03 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=180324.554229 records/second
# [05/31/2018 00:26:03 INFO 140523443300160] #quality_metric: host=algo-1, epoch=27, batch=0 train rmse <loss>=0.917557720479
# [05/31/2018 00:26:04 INFO 140523443300160] #quality_metric: host=algo-1, epoch=27, train rmse <loss>=0.966163186165
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 354.72893714904785, "sum": 354.72893714904785, "min": 354.72893714904785}}, "EndTime": 1527726364.054162, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726363.698812}
#
# [05/31/2018 00:26:04 INFO 140523443300160] #progress_metric: host=algo-1, completed 28 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 1989, "sum": 1989.0, "min": 1989}, "Total Records Seen": {"count": 1, "max": 1961056, "sum": 1961056.0, "min": 1961056}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 29, "sum": 29.0, "min": 29}}, "EndTime": 1527726364.05445, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 27}, "StartTime": 1527726364.054392}
#
# ...
#
# [05/31/2018 00:26:28 INFO 140523443300160] #progress_metric: host=algo-1, completed 92 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6533, "sum": 6533.0, "min": 6533}, "Total Records Seen": {"count": 1, "max": 6441184, "sum": 6441184.0, "min": 6441184}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 93, "sum": 93.0, "min": 93}}, "EndTime": 1527726388.633517, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 91}, "StartTime": 1527726388.633454}
#
# [05/31/2018 00:26:28 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=170246.204439 records/second
# [05/31/2018 00:26:28 INFO 140523443300160] #quality_metric: host=algo-1, epoch=92, batch=0 train rmse <loss>=0.84472513096
# [05/31/2018 00:26:29 INFO 140523443300160] #quality_metric: host=algo-1, epoch=92, train rmse <loss>=0.897434012653
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 382.50112533569336, "sum": 382.50112533569336, "min": 382.50112533569336}}, "EndTime": 1527726389.016437, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726388.633062}
#
# [05/31/2018 00:26:29 INFO 140523443300160] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6604, "sum": 6604.0, "min": 6604}, "Total Records Seen": {"count": 1, "max": 6511186, "sum": 6511186.0, "min": 6511186}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 94, "sum": 94.0, "min": 94}}, "EndTime": 1527726389.016716, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 92}, "StartTime": 1527726389.016659}
#
# [05/31/2018 00:26:29 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=182815.798979 records/second
# [05/31/2018 00:26:29 INFO 140523443300160] #quality_metric: host=algo-1, epoch=93, batch=0 train rmse <loss>=0.844051848496
# [05/31/2018 00:26:29 INFO 140523443300160] #quality_metric: host=algo-1, epoch=93, train rmse <loss>=0.896824507944
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 384.02295112609863, "sum": 384.02295112609863, "min": 384.02295112609863}}, "EndTime": 1527726389.401252, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726389.016519}
#
# [05/31/2018 00:26:29 INFO 140523443300160] #progress_metric: host=algo-1, completed 94 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6675, "sum": 6675.0, "min": 6675}, "Total Records Seen": {"count": 1, "max": 6581188, "sum": 6581188.0, "min": 6581188}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 95, "sum": 95.0, "min": 95}}, "EndTime": 1527726389.401505, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 93}, "StartTime": 1527726389.401463}
#
# [05/31/2018 00:26:29 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=182109.151867 records/second
# [05/31/2018 00:26:29 INFO 140523443300160] #quality_metric: host=algo-1, epoch=94, batch=0 train rmse <loss>=0.84338475891
# [05/31/2018 00:26:29 INFO 140523443300160] #quality_metric: host=algo-1, epoch=94, train rmse <loss>=0.896221414368
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 375.20885467529297, "sum": 375.20885467529297, "min": 375.20885467529297}}, "EndTime": 1527726389.777064, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726389.401324}
#
# [05/31/2018 00:26:29 INFO 140523443300160] #progress_metric: host=algo-1, completed 95 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6746, "sum": 6746.0, "min": 6746}, "Total Records Seen": {"count": 1, "max": 6651190, "sum": 6651190.0, "min": 6651190}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 96, "sum": 96.0, "min": 96}}, "EndTime": 1527726389.777361, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 94}, "StartTime": 1527726389.7773}
#
# [05/31/2018 00:26:29 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=186354.470969 records/second
# [05/31/2018 00:26:29 INFO 140523443300160] #quality_metric: host=algo-1, epoch=95, batch=0 train rmse <loss>=0.842723768271
# [05/31/2018 00:26:30 INFO 140523443300160] #quality_metric: host=algo-1, epoch=95, train rmse <loss>=0.895624578825
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 355.0100326538086, "sum": 355.0100326538086, "min": 355.0100326538086}}, "EndTime": 1527726390.132701, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726389.777139}
#
# [05/31/2018 00:26:30 INFO 140523443300160] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6817, "sum": 6817.0, "min": 6817}, "Total Records Seen": {"count": 1, "max": 6721192, "sum": 6721192.0, "min": 6721192}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1527726390.133013, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 95}, "StartTime": 1527726390.132954}
#
# [05/31/2018 00:26:30 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=196941.912506 records/second
# [05/31/2018 00:26:30 INFO 140523443300160] #quality_metric: host=algo-1, epoch=96, batch=0 train rmse <loss>=0.842068637252
# [05/31/2018 00:26:30 INFO 140523443300160] #quality_metric: host=algo-1, epoch=96, train rmse <loss>=0.895033801572
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 421.94676399230957, "sum": 421.94676399230957, "min": 421.94676399230957}}, "EndTime": 1527726390.555278, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726390.132771}
#
# [05/31/2018 00:26:30 INFO 140523443300160] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6888, "sum": 6888.0, "min": 6888}, "Total Records Seen": {"count": 1, "max": 6791194, "sum": 6791194.0, "min": 6791194}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1527726390.555576, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 96}, "StartTime": 1527726390.555518}
#
# [05/31/2018 00:26:30 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=165735.845523 records/second
# [05/31/2018 00:26:30 INFO 140523443300160] #quality_metric: host=algo-1, epoch=97, batch=0 train rmse <loss>=0.84141937954
# [05/31/2018 00:26:30 INFO 140523443300160] #quality_metric: host=algo-1, epoch=97, train rmse <loss>=0.894448984085
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 378.18121910095215, "sum": 378.18121910095215, "min": 378.18121910095215}}, "EndTime": 1527726390.934219, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726390.555353}
#
# [05/31/2018 00:26:30 INFO 140523443300160] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 6959, "sum": 6959.0, "min": 6959}, "Total Records Seen": {"count": 1, "max": 6861196, "sum": 6861196.0, "min": 6861196}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1527726390.934493, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1527726390.934438}
#
# [05/31/2018 00:26:30 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=184876.090256 records/second
# [05/31/2018 00:26:30 INFO 140523443300160] #quality_metric: host=algo-1, epoch=98, batch=0 train rmse <loss>=0.840775718366
# [05/31/2018 00:26:31 INFO 140523443300160] #quality_metric: host=algo-1, epoch=98, train rmse <loss>=0.893869963994
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 374.2818832397461, "sum": 374.2818832397461, "min": 374.2818832397461}}, "EndTime": 1527726391.309156, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726390.934294}
#
# [05/31/2018 00:26:31 INFO 140523443300160] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 7030, "sum": 7030.0, "min": 7030}, "Total Records Seen": {"count": 1, "max": 6931198, "sum": 6931198.0, "min": 6931198}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1527726391.309423, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1527726391.309371}
#
# [05/31/2018 00:26:31 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=186843.416632 records/second
# [05/31/2018 00:26:31 INFO 140523443300160] #quality_metric: host=algo-1, epoch=99, batch=0 train rmse <loss>=0.840137557619
# [05/31/2018 00:26:31 INFO 140523443300160] #quality_metric: host=algo-1, epoch=99, train rmse <loss>=0.8932965755
# [05/31/2018 00:26:31 INFO 140523443300160] #quality_metric: host=algo-1, train rmse <loss>=0.8932965755
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 384.37819480895996, "sum": 384.37819480895996, "min": 384.37819480895996}}, "EndTime": 1527726391.69408, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726391.309237}
#
# [05/31/2018 00:26:31 INFO 140523443300160] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Total Batches Seen": {"count": 1, "max": 7101, "sum": 7101.0, "min": 7101}, "Total Records Seen": {"count": 1, "max": 7001200, "sum": 7001200.0, "min": 7001200}, "Max Records Seen Between Resets": {"count": 1, "max": 70002, "sum": 70002.0, "min": 70002}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1527726391.694366, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1527726391.694313}
#
# [05/31/2018 00:26:31 INFO 140523443300160] #throughput_metric: host=algo-1, train throughput=181928.72087 records/second
# [05/31/2018 00:26:31 WARNING 140523443300160] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/31/2018 00:26:31 INFO 140523443300160] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 3.340005874633789, "sum": 3.340005874633789, "min": 3.340005874633789}}, "EndTime": 1527726391.698059, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726391.69415}
#
# [05/31/2018 00:26:31 INFO 140523443300160] Saved checkpoint to "/tmp/tmpBXs2bK/state-0001.params"
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Number of Batches Since Last Reset": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Number of Records Since Last Reset": {"count": 1, "max": 30002, "sum": 30002.0, "min": 30002}, "Total Batches Seen": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Total Records Seen": {"count": 1, "max": 30002, "sum": 30002.0, "min": 30002}, "Max Records Seen Between Resets": {"count": 1, "max": 30002, "sum": 30002.0, "min": 30002}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1527726391.79104, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726391.790973}
#
# [05/31/2018 00:26:31 INFO 140523443300160] #test_score (algo-1) : ('rmse', 0.8963397926372807)
# [05/31/2018 00:26:31 INFO 140523443300160] #quality_metric: host=algo-1, test rmse <loss>=0.896339792637
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 38963.39297294617, "sum": 38963.39297294617, "min": 38963.39297294617}, "setuptime": {"count": 1, "max": 46.38481140136719, "sum": 46.38481140136719, "min": 46.38481140136719}}, "EndTime": 1527726391.79339, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1527726391.698129}
# ===== Job Complete =====
# Billable seconds: 156

# %% [markdown]
# ## Deploy Model

# %%
# Ref: http://sagemaker.readthedocs.io/en/latest/estimators.html
predictor = estimator.deploy(initial_instance_count=1,
                             instance_type='ml.m4.xlarge',
                             endpoint_name = 'fm-movie-v2')
# Out:
# INFO:sagemaker:Creating model with name: factorization-machines-2018-05-31-00-28-15-636
# INFO:sagemaker:Creating endpoint with name fm-movie-v2
# --------------------------------------------------------------------------!

# %% [markdown]
# ## Run Predictions
# ### Dense and Sparse Formats
# https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-inference.html

# %%
import json
from sagemaker.predictor import json_deserializer

dim_movie = 9737
def fm_sparse_serializer(data):
    js = {'instances': []}
    for row in data:
        
        column_list = row.tolist()
        value_list = np.ones(len(column_list),dtype=int).tolist()
       
        js['instances'].append({'data':{'features': { 'keys': column_list, 'shape':[dim_movie], 'values': value_list}}})
    return json.dumps(js)

# %%
predictor.content_type = 'application/json'
predictor.serializer = fm_sparse_serializer
predictor.deserializer = json_deserializer

# %%
import numpy as np

# %%
fm_sparse_serializer([np.array([341,1416])])
# Out:
# '{"instances": [{"data": {"features": {"keys": [341, 1416], "shape": [9737], "values": [1, 1]}}}]}'

# %%
# Rating Entry: ['5 341:1 1416:1', '2.5 209:1 2640:1','2.5 164:1 1346:1']
predictor.predict([np.array([341,1416])])
# Out:
# {'predictions': [{'score': 4.107213020324707}]}

# %% [markdown]
# ## Summary

# %% [markdown]
# 1. Ensure Training, Test and Validation data are in S3 Bucket
# 2. Select Algorithm Container Registry Path - Path varies by region
# 3. Configure Estimator for training - Specify Algorithm container, instance count, instance type, model output location
# 4. Specify algorithm specific hyper parameters
# 5. Train model
# 6. Deploy model - Specify instance count, instance type and endpoint name
# 7. Run Predictions
